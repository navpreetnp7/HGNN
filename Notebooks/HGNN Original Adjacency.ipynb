# %%
import argparse
import numpy as np
import time

import torch
import torch.optim as optim

from utils import load_data,svdApprox,nmi_score,normalize
#from GNN import GraphNeuralNet
import pycombo
import networkx as nx

import torch.nn as nn
import torch.nn.functional as F
from layers import GraphNN1, GraphNN1_h, GraphNN2, InnerProduct
from utils import doublerelu


import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
torch.set_printoptions(sci_mode=False)
np.set_printoptions(suppress=True)

# %%
# Training settings
parser = argparse.ArgumentParser()
parser.add_argument('--no-cuda', action='store_true', default=False,
                    help='Disables CUDA training.')
parser.add_argument('--fastmode', action='store_true', default=False,
                    help='Validate during training pass.')
parser.add_argument('--seed', type=int, default=426, help='Random seed.')
parser.add_argument('--epochs', type=int, default=20001,
                    help='Number of epochs to train.')
parser.add_argument('--lr', type=float, default=0.00001,
                    help='Initial learning rate.')
parser.add_argument('--weight_decay', type=float, default=10e-4,
                    help='Weight decay (L2 loss on parameters).')
parser.add_argument('--hidden', type=int, default=16,
                    help='Number of hidden units.')
parser.add_argument('--ndim', type=int, default=5,
                    help='Embeddings dimension.')

args = parser.parse_args(args=[])
args.cuda = not args.no_cuda and torch.cuda.is_available()

# %%
if 1:
    # Taxi Dataset Graph
    adj = load_data()
    #adj = load_data(daily=True)
else:
    #Toy Example Graph
    adj = toy_data()

# %%
from torch.nn.parameter import Parameter
from torch.nn.modules.module import Module

class GraphNN1(Module):

    def __init__(self, batch_size, in_features, out_features, fixed):
        super(GraphNN1, self).__init__()

        self.batch_size = batch_size
        self.in_features = in_features
        self.out_features = out_features
        self.fixed = fixed
        weight0_eye = torch.FloatTensor(torch.eye(in_features,out_features))
        weight0_eye = weight0_eye.reshape((1, in_features, out_features))
        weight0_eye = weight0_eye.repeat(batch_size, 1, 1)
        self.weight0 = Parameter(weight0_eye)
        self.weight1 = Parameter(torch.zeros(batch_size, in_features, out_features))


    def forward(self, input, adj):
        v1 = torch.bmm(input, self.weight0)
        v2 = torch.bmm(torch.bmm(adj, input),self.weight1)
        output = v1 + v2
        return output

    def __repr__(self):
        return self.__class__.__name__ + ' (' \
               + str(self.in_features) + ' -> ' \
               + str(self.out_features) + ')'

# %%
from torch.nn.parameter import Parameter
from torch.nn.modules.module import Module

class GraphNN2(Module):

    def __init__(self, batch_size, in_features, out_features, fixed):
        super(GraphNN2, self).__init__()

        self.batch_size = batch_size
        self.in_features = in_features
        self.out_features = out_features
        self.fixed = fixed
        weight0_eye = torch.FloatTensor(torch.eye(in_features,in_features))
        weight0_eye = weight0_eye.reshape((1, in_features, in_features))
        weight0_eye = weight0_eye.repeat(batch_size, 1, 1)
        weight0_rand = torch.empty(batch_size,in_features,out_features-in_features)
        torch.nn.init.xavier_uniform_(weight0_rand, gain=1.0)
        self.weight0 = Parameter(torch.cat((weight0_eye,weight0_rand),dim=2))
        self.weight1 = Parameter(torch.zeros(batch_size, in_features, out_features))


    def forward(self, input, adj):
        v1 = torch.bmm(input, self.weight0)
        v2 = torch.bmm(torch.bmm(adj, input),self.weight1)
        output = v1 + v2
        return output

    def __repr__(self):
        return self.__class__.__name__ + ' (' \
               + str(self.in_features) + ' -> ' \
               + str(self.out_features) + ')'

# %%
class GNN1Layer(nn.Module):

    def __init__(self, batch_size, nfeat, hidden, ndim, fixed):
        super(GNN1Layer, self).__init__()

        self.batch_size = batch_size
        self.nfeat = nfeat
        if fixed:
            self.ndim = 2*ndim
            self.hidden = hidden
        else:
            self.ndim = 4*ndim
            self.hidden = 2*hidden
        self.fixed = fixed

        self.x1 = GraphNN1(batch_size, self.ndim, self.ndim, fixed)
        #self.x2 = GraphNN1(batch_size, self.hidden*self.ndim, self.ndim, fixed)
        
        self.reconstructions = InnerProduct(self.ndim)

    def forward(self, x, adj):

        #scale weights for sigmoid
        scale = 1000
        x = x/scale
        x = torch.sigmoid(x)
        x1 = doublerelu(self.x1(x, adj))
        x2 = torch.logit(x1)

        # rescale back to original weights
        x2 = x2*scale
        if self.fixed:
            mu = F.relu(self.reconstructions(x2))
            return mu, x2
        else:
            lr1, lr2 = torch.chunk(x2, chunks=2, dim=2)
            mu = F.relu(self.reconstructions(lr1))
            sigma = F.relu(self.reconstructions(lr2))
            return mu, sigma, x2

# %%
class GNN2Layer(nn.Module):

    def __init__(self, batch_size, nfeat, hidden, ndim, fixed):
        super(GNN2Layer, self).__init__()

        self.batch_size = batch_size
        self.nfeat = nfeat
        if fixed:
            self.ndim = 2*ndim
            self.hidden = hidden
        else:
            self.ndim = 4*ndim
            self.hidden = 2*hidden
        self.fixed = fixed

        self.x1 = GraphNN2(batch_size, self.ndim, self.hidden*self.ndim, fixed)
        self.x2 = GraphNN1(batch_size, self.hidden*self.ndim, self.ndim, fixed)
        
        self.reconstructions = InnerProduct(self.ndim)

    def forward(self, x, adj):

        #scale weights for sigmoid
        scale = 1000
        x = x/scale
        x = torch.sigmoid(x)
        x1 = doublerelu(self.x1(x, adj))
        x2 = doublerelu(self.x2(x1, adj))
        x2 = torch.logit(x2)

        # rescale back to original weights
        x2 = x2*scale
        if self.fixed:
            mu = F.relu(self.reconstructions(x2))
            return mu, x2
        else:
            lr1, lr2 = torch.chunk(x2, chunks=2, dim=2)
            mu = F.relu(self.reconstructions(lr1))
            sigma = F.relu(self.reconstructions(lr2))
            return mu, sigma, x2

# %%
def GraphNeuralNet(adj,dim,hidden,fixed,features,GNN):

    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    if args.cuda:
        torch.cuda.manual_seed(args.seed)
    
    adj = torch.FloatTensor(np.array(adj))
    
    #adj_norm = normalize(adj)
    adj_norm = F.normalize(adj,dim=2)

    # loss function
    criterion = torch.nn.GaussianNLLLoss()

    # NULL Model
    mu0 = adj.mean() * torch.ones(adj.shape[1:])
    sigma0 = adj.std() * torch.ones(adj.shape[1:])
    with torch.no_grad():
        loss0 = criterion(torch.flatten(adj), torch.flatten(mu0), torch.flatten(torch.square(sigma0)))

    # Model and optimizer

    model = GNN(batch_size=adj.shape[0],
                nfeat=features.shape[1],
                hidden=hidden,
                ndim=dim,
                fixed=fixed)

    if args.cuda:
        model = model.cuda()
        features = features.cuda()
        adj = adj.cuda()
        adj_norm = adj_norm.cuda()

    # Train model
    t_total = time.time()

    optimizer = optim.Adam(model.parameters(),
                           lr=args.lr, weight_decay=args.weight_decay)


    for epoch in range(args.epochs):

        t = time.time()
        model.train()
        optimizer.zero_grad()

        if fixed:
            mu,lr = model(features, adj_norm)
            with torch.no_grad():
                mse = torch.nn.MSELoss()
                mseloss = mse(torch.flatten(mu), torch.flatten(adj))
                sig = torch.sqrt(mseloss)
            sigma = sig * torch.ones(adj.shape, requires_grad=True).cuda()
        else:
            mu, sigma,lr = model(features, adj_norm)

        loss = criterion(torch.flatten(adj), torch.flatten(mu), torch.flatten(torch.square(sigma)))
        loss.backward(retain_graph=True)

        optimizer.step()

        if epoch == 0:
            best_loss = loss
            best_lr = lr
            best_mu = mu
            if fixed:
                best_sig = sig
        else:
            if loss < best_loss:
                best_loss = loss
                best_lr = lr
                best_mu = mu
                if fixed:
                    best_sig = sig

        if epoch % 5000 == 0:
            print('Epoch: {:04d}'.format(epoch + 1),
                  'loss: {:.8f}'.format(best_loss.item()),
                  'time: {:.4f}s'.format(time.time() - t))

    print("Optimization Finished!")
    print("Total time elapsed: {:.4f}s".format(time.time() - t_total))

    if fixed:
        return best_lr, best_sig, best_mu, best_loss
    else:
        return best_lr, best_mu, best_loss

# %%
def HGNN(adj,dim,hidden,fixed):
    
    #partition using pycombo
    G = nx.from_numpy_matrix(np.array(adj[0]))
    partition = pycombo.execute(G, random_seed = args.seed)
    
    #get binary matrix of the partition and inverse community disaggregation mapping
    nb_community = max(list(partition[0].values())) + 1
    communities =  np.array(list(partition[0].values())).reshape(-1)
    C = np.eye(nb_community)[communities]
    C = torch.Tensor(C).unsqueeze(0)
    
    #perform svd on orig network
    _,sig,_,svd_embedx,svd_embedy = svdApprox(adj,dim)
    svd_embed = torch.cat([svd_embedx,svd_embedy],dim=1)
    if not fixed:
        svd_sigma = torch.ones(svd_embed.shape) * torch.sqrt(sig / dim)
        svd_embed = torch.cat([svd_embed,svd_sigma],dim=1)

    features = torch.FloatTensor(svd_embed)
    features = features.unsqueeze(0)
    
    

    if fixed:
        embed, sigma, mu, loss = GraphNeuralNet(adj=adj, dim=dim, hidden=hidden, fixed=True, features=features, GNN=GNN1Layer)
        return embed, sigma, mu, loss
    else:
        embed, mu, loss = GraphNeuralNet(adj=adj, dim=dim, hidden=hidden, fixed=False, features=features, GNN=GNN1Layer)
        return embed, mu, loss

# %%
def HGNN_embed(adj,dim):
    
    print("\nFixed Sigma dim {}\n".format(dim))
    
    lr,sig,fix_mu,fix_loss = HGNN(adj,dim,4,True)
    
    sigma = torch.ones(lr.shape).cuda() * torch.sqrt(sig/dim)
    features = torch.cat([lr,sigma],dim=2).cpu().detach()
    features = torch.Tensor(features)
    

    print("\nFlexible Sigma dim {}\n".format(dim))
    embed, flex_mu, flex_loss = GraphNeuralNet(adj=adj, dim=dim, hidden=4, fixed=False, features=features, GNN=GNN1Layer)
    
    print("\n2 Layer dim {}\n".format(dim))
    embed, flex_mu, flex_loss = GraphNeuralNet(adj=adj, dim=dim, hidden=4, fixed=False, features=embed.detach(), GNN=GNN2Layer)
    
    
    return embed, fix_mu, flex_mu, fix_loss, flex_loss

# %%
fix_loss = []
nonfix_loss = []
svd_loss = []
svdrelu_loss = []
nmi_fix = []
nmi_nonfix = []
nmi_svd = []
nmi_svdrelu = []
dims = [x for x in range(1,15)]

for dim in dims:
    
    fixembed, fix_mu, flex_mu, fixloss, flexloss = HGNN_embed(adj,dim)
    fix_loss.append(fixloss)
    nmi_fix.append(nmi_score(adj[0],fix_mu.reshape(adj.shape[1:]).cpu().detach()))
    nonfix_loss.append(flexloss)
    nmi_nonfix.append(nmi_score(adj[0],flex_mu.reshape(adj.shape[1:]).cpu().detach()))
    
    mu,sig,loss,embedx,embedy = svdApprox(adj=adj,dim=dim)
    svd_loss.append(loss)
    nmi_svd.append(nmi_score(adj[0],mu.reshape(adj.shape[1:]).cpu().detach()))
    mu,sig,loss,embedx,embedy = svdApprox(adj=adj,dim=dim,relu=True)
    svdrelu_loss.append(loss)
    nmi_svdrelu.append(nmi_score(adj[0],mu.reshape(adj.shape[1:]).cpu().detach()))
# Out:
# Fixed Sigma dim 1
#
# Epoch: 0001 loss: 10.95440483 time: 0.4552s
# Epoch: 5001 loss: 10.95440388 time: 0.0000s
# Epoch: 10001 loss: 10.95440388 time: 0.0000s
# Epoch: 15001 loss: 10.95440388 time: 0.0000s
# Epoch: 20001 loss: 10.95440388 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 73.0188s
#
# Flexible Sigma dim 1
#
# Epoch: 0001 loss: 10.95440388 time: 0.0000s
# Epoch: 5001 loss: 10.12933254 time: 0.0000s
# Epoch: 10001 loss: 10.03185081 time: 0.0000s
# Epoch: 15001 loss: 9.86146545 time: 0.0000s
# Epoch: 20001 loss: 9.74318886 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 56.3237s
#
# 2 Layer dim 1
#
# Epoch: 0001 loss: 9.74318981 time: 0.0100s
# Epoch: 5001 loss: 9.73958874 time: 0.0030s
# Epoch: 10001 loss: 9.15141296 time: 0.0000s
# Epoch: 15001 loss: 9.15141296 time: 0.0000s
# Epoch: 20001 loss: 9.15141296 time: 0.0156s
# Optimization Finished!
# Total time elapsed: 79.4791s
#
# Fixed Sigma dim 2
#
# Epoch: 0001 loss: 10.72826767 time: 0.0000s
# Epoch: 5001 loss: 10.72769833 time: 0.0000s
# Epoch: 10001 loss: 10.72769833 time: 0.0156s
# Epoch: 15001 loss: 10.72769833 time: 0.0000s
# Epoch: 20001 loss: 10.72769642 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 85.1975s
#
# Flexible Sigma dim 2
#
# Epoch: 0001 loss: 10.72769833 time: 0.0000s
# Epoch: 5001 loss: 10.01784801 time: 0.0000s
# Epoch: 10001 loss: 10.01784801 time: 0.0000s
# Epoch: 15001 loss: 10.01784801 time: 0.0000s
# Epoch: 20001 loss: 10.01784801 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 60.7499s
#
# 2 Layer dim 2
#
# Epoch: 0001 loss: 10.01786041 time: 0.0000s
# Epoch: 5001 loss: 9.98946476 time: 0.0000s
# Epoch: 10001 loss: 9.95967960 time: 0.0000s
# Epoch: 15001 loss: 9.95967960 time: 0.0000s
# Epoch: 20001 loss: 9.95967960 time: 0.0115s
# Optimization Finished!
# Total time elapsed: 91.3993s
#
# Fixed Sigma dim 3
#
# Epoch: 0001 loss: 10.41265488 time: 0.0000s
# Epoch: 5001 loss: 10.40987587 time: 0.0156s
# Epoch: 10001 loss: 10.40974045 time: 0.0000s
# Epoch: 15001 loss: 10.40966702 time: 0.0000s
# Epoch: 20001 loss: 10.40961456 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 90.9585s
#
# Flexible Sigma dim 3
#
# Epoch: 0001 loss: 10.40961552 time: 0.0000s
# Epoch: 5001 loss: 9.94468880 time: 0.0000s
# Epoch: 10001 loss: 9.89329624 time: 0.0000s
# Epoch: 15001 loss: 9.89329624 time: 0.0000s
# Epoch: 20001 loss: 9.89329624 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 62.6382s
#
# 2 Layer dim 3
#
# Epoch: 0001 loss: 9.89329624 time: 0.0000s
# Epoch: 5001 loss: 9.72448921 time: 0.0000s
# Epoch: 10001 loss: 9.71744823 time: 0.0040s
# Epoch: 15001 loss: 9.71744823 time: 0.0000s
# Epoch: 20001 loss: 9.71744823 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 84.9588s
#
# Fixed Sigma dim 4
#
# Epoch: 0001 loss: 10.20869160 time: 0.0000s
# Epoch: 5001 loss: 10.19353580 time: 0.0156s
# Epoch: 10001 loss: 10.19238377 time: 0.0000s
# Epoch: 15001 loss: 10.19192028 time: 0.0000s
# Epoch: 20001 loss: 10.19171047 time: 0.0156s
# Optimization Finished!
# Total time elapsed: 82.2570s
#
# Flexible Sigma dim 4
#
# Epoch: 0001 loss: 10.19171143 time: 0.0105s
# Epoch: 5001 loss: 9.86150074 time: 0.0000s
# Epoch: 10001 loss: 9.85304546 time: 0.0000s
# Epoch: 15001 loss: 9.84397411 time: 0.0000s
# Epoch: 20001 loss: 9.84397411 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 66.9120s
#
# 2 Layer dim 4
#
# Epoch: 0001 loss: 9.84397697 time: 0.0156s
# Epoch: 5001 loss: 9.61404419 time: 0.0000s
# Epoch: 10001 loss: 9.61404419 time: 0.0000s
# Epoch: 15001 loss: 9.61404419 time: 0.0000s
# Epoch: 20001 loss: 9.61404419 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 84.0811s
#
# Fixed Sigma dim 5
#
# Epoch: 0001 loss: 10.08040905 time: 0.0000s
# Epoch: 5001 loss: 10.05765247 time: 0.0000s
# Epoch: 10001 loss: 10.05487442 time: 0.0000s
# Epoch: 15001 loss: 10.05369854 time: 0.0000s
# Epoch: 20001 loss: 10.05315590 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 84.5400s
#
# Flexible Sigma dim 5
#
# Epoch: 0001 loss: 10.05315590 time: 0.0000s
# Epoch: 5001 loss: 9.77427197 time: 0.0000s
# Epoch: 10001 loss: 9.77427197 time: 0.0000s
# Epoch: 15001 loss: 9.77427197 time: 0.0000s
# Epoch: 20001 loss: 9.77427197 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 64.6253s
#
# 2 Layer dim 5
#
# Epoch: 0001 loss: 9.77427197 time: 0.0000s
# Epoch: 5001 loss: 9.61757946 time: 0.0000s
# Epoch: 10001 loss: 9.57682323 time: 0.0000s
# Epoch: 15001 loss: 9.52547169 time: 0.0000s
# Epoch: 20001 loss: 9.52547169 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 81.2840s
#
# Fixed Sigma dim 6
#
# Epoch: 0001 loss: 9.98619270 time: 0.0000s
# Epoch: 5001 loss: 9.97509193 time: 0.0156s
# Epoch: 10001 loss: 9.97371674 time: 0.0156s
# Epoch: 15001 loss: 9.97336578 time: 0.0000s
# Epoch: 20001 loss: 9.97318554 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 84.0343s
#
# Flexible Sigma dim 6
#
# Epoch: 0001 loss: 9.97318554 time: 0.0000s
# Epoch: 5001 loss: 9.74596786 time: 0.0000s
# Epoch: 10001 loss: 9.74596786 time: 0.0000s
# Epoch: 15001 loss: 9.74596786 time: 0.0040s
# Epoch: 20001 loss: 9.74596786 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 64.5172s
#
# 2 Layer dim 6
#
# Epoch: 0001 loss: 9.74596882 time: 0.0040s
# Epoch: 5001 loss: 9.62201500 time: 0.0157s
# Epoch: 10001 loss: 9.62201500 time: 0.0000s
# Epoch: 15001 loss: 9.62201500 time: 0.0157s
# Epoch: 20001 loss: 9.62201500 time: 0.0156s
# Optimization Finished!
# Total time elapsed: 80.7057s
#
# Fixed Sigma dim 7
#
# Epoch: 0001 loss: 9.89500713 time: 0.0000s
# Epoch: 5001 loss: 9.88691521 time: 0.0000s
# Epoch: 10001 loss: 9.88626862 time: 0.0000s
# Epoch: 15001 loss: 9.88588619 time: 0.0000s
# Epoch: 20001 loss: 9.88563728 time: 0.0156s
# Optimization Finished!
# Total time elapsed: 82.9188s
#
# Flexible Sigma dim 7
#
# Epoch: 0001 loss: 9.88563824 time: 0.0166s
# Epoch: 5001 loss: 9.65086365 time: 0.0000s
# Epoch: 10001 loss: 9.65086365 time: 0.0000s
# Epoch: 15001 loss: 9.65086365 time: 0.0000s
# Epoch: 20001 loss: 9.65086365 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 65.7827s
#
# 2 Layer dim 7
#
# Epoch: 0001 loss: 9.65086365 time: 0.0000s
# Epoch: 5001 loss: 9.50546265 time: 0.0000s
# Epoch: 10001 loss: 9.50546265 time: 0.0000s
# Epoch: 15001 loss: 9.50546265 time: 0.0156s
# Epoch: 20001 loss: 9.50546265 time: 0.0156s
# Optimization Finished!
# Total time elapsed: 81.5954s
#
# Fixed Sigma dim 8
#
# Epoch: 0001 loss: 9.81505680 time: 0.0000s
# Epoch: 5001 loss: 9.80721474 time: 0.0156s
# Epoch: 10001 loss: 9.80331993 time: 0.0156s
# Epoch: 15001 loss: 9.80134869 time: 0.0035s
# Epoch: 20001 loss: 9.80026627 time: 0.0156s
# Optimization Finished!
# Total time elapsed: 80.8459s
#
# Flexible Sigma dim 8
#
# Epoch: 0001 loss: 9.80026722 time: 0.0156s
# Epoch: 5001 loss: 9.46111679 time: 0.0156s
# Epoch: 10001 loss: 9.46111679 time: 0.0156s
# Epoch: 15001 loss: 9.46111679 time: 0.0000s
# Epoch: 20001 loss: 9.46111679 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 70.7405s
#
# 2 Layer dim 8
#
# Epoch: 0001 loss: 9.46111679 time: 0.0000s
# Epoch: 5001 loss: 9.46111679 time: 0.0000s
# Epoch: 10001 loss: 9.45736408 time: 0.0000s
# Epoch: 15001 loss: 9.45736408 time: 0.0157s
# Epoch: 20001 loss: 9.45736408 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 83.5921s
#
# Fixed Sigma dim 9
#
# Epoch: 0001 loss: 9.73391914 time: 0.0000s
# Epoch: 5001 loss: 9.72470665 time: 0.0156s
# Epoch: 10001 loss: 9.72169113 time: 0.0156s
# Epoch: 15001 loss: 9.71901321 time: 0.0000s
# Epoch: 20001 loss: 9.71383476 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 79.7009s
#
# Flexible Sigma dim 9
#
# Epoch: 0001 loss: 9.71383476 time: 0.0000s
# Epoch: 5001 loss: 9.39556026 time: 0.0000s
# Epoch: 10001 loss: 9.39556026 time: 0.0000s
# Epoch: 15001 loss: 9.39556026 time: 0.0156s
# Epoch: 20001 loss: 9.39556026 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 70.0284s
#
# 2 Layer dim 9
#
# Epoch: 0001 loss: 9.39556026 time: 0.0000s
# Epoch: 5001 loss: 9.27600384 time: 0.0040s
# Epoch: 10001 loss: 9.27600384 time: 0.0040s
# Epoch: 15001 loss: 9.27600384 time: 0.0120s
# Epoch: 20001 loss: 9.27600384 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 83.8633s
#
# Fixed Sigma dim 10
#
# Epoch: 0001 loss: 9.65957642 time: 0.0000s
# Epoch: 5001 loss: 9.64981461 time: 0.0000s
# Epoch: 10001 loss: 9.64733505 time: 0.0040s
# Epoch: 15001 loss: 9.64584160 time: 0.0150s
# Epoch: 20001 loss: 9.64447403 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 84.6621s
#
# Flexible Sigma dim 10
#
# Epoch: 0001 loss: 9.64447403 time: 0.0000s
# Epoch: 5001 loss: 9.35477161 time: 0.0040s
# Epoch: 10001 loss: 9.35477161 time: 0.0080s
# Epoch: 15001 loss: 9.35477161 time: 0.0000s
# Epoch: 20001 loss: 9.35477161 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 66.4150s
#
# 2 Layer dim 10
#
# Epoch: 0001 loss: 9.35477066 time: 0.0140s
# Epoch: 5001 loss: 9.30329132 time: 0.0000s
# Epoch: 10001 loss: 9.28375912 time: 0.0000s
# Epoch: 15001 loss: 9.28375912 time: 0.0000s
# Epoch: 20001 loss: 9.28375912 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 82.7321s
#
# Fixed Sigma dim 11
#
# Epoch: 0001 loss: 9.57401943 time: 0.0000s
# Epoch: 5001 loss: 9.55813599 time: 0.0000s
# Epoch: 10001 loss: 9.55473804 time: 0.0000s
# Epoch: 15001 loss: 9.55294991 time: 0.0000s
# Epoch: 20001 loss: 9.55164337 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 81.3528s
#
# Flexible Sigma dim 11
#
# Epoch: 0001 loss: 9.55164337 time: 0.0000s
# Epoch: 5001 loss: 9.25942039 time: 0.0000s
# Epoch: 10001 loss: 9.25942039 time: 0.0000s
# Epoch: 15001 loss: 9.25942039 time: 0.0000s
# Epoch: 20001 loss: 9.25942039 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 67.8462s
#
# 2 Layer dim 11
#
# Epoch: 0001 loss: 9.25942135 time: 0.0000s
# Epoch: 5001 loss: 9.24065495 time: 0.0000s
# Epoch: 10001 loss: 9.24065495 time: 0.0000s
# Epoch: 15001 loss: 9.24065495 time: 0.0000s
# Epoch: 20001 loss: 9.24065495 time: 0.0156s
# Optimization Finished!
# Total time elapsed: 81.1350s
#
# Fixed Sigma dim 12
#
# Epoch: 0001 loss: 9.52081776 time: 0.0000s
# Epoch: 5001 loss: 9.51570606 time: 0.0000s
# Epoch: 10001 loss: 9.51473045 time: 0.0000s
# Epoch: 15001 loss: 9.51404285 time: 0.0000s
# Epoch: 20001 loss: 9.51347733 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 79.7018s
#
# Flexible Sigma dim 12
#
# Epoch: 0001 loss: 9.51347733 time: 0.0000s
# Epoch: 5001 loss: 9.34299946 time: 0.0000s
# Epoch: 10001 loss: 9.34299946 time: 0.0115s
# Epoch: 15001 loss: 9.34299946 time: 0.0000s
# Epoch: 20001 loss: 9.34299946 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 66.0310s
#
# 2 Layer dim 12
#
# Epoch: 0001 loss: 9.34299946 time: 0.0000s
# Epoch: 5001 loss: 9.29440880 time: 0.0000s
# Epoch: 10001 loss: 9.29440880 time: 0.0000s
# Epoch: 15001 loss: 9.29440880 time: 0.0000s
# Epoch: 20001 loss: 9.29440880 time: 0.0040s
# Optimization Finished!
# Total time elapsed: 85.3175s
#
# Fixed Sigma dim 13
#
# Epoch: 0001 loss: 9.46569920 time: 0.0080s
# Epoch: 5001 loss: 9.45930386 time: 0.0156s
# Epoch: 10001 loss: 9.45838928 time: 0.0000s
# Epoch: 15001 loss: 9.45760059 time: 0.0000s
# Epoch: 20001 loss: 9.45697880 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 79.7330s
#
# Flexible Sigma dim 13
#
# Epoch: 0001 loss: 9.45697975 time: 0.0000s
# Epoch: 5001 loss: 9.32320023 time: 0.0160s
# Epoch: 10001 loss: 9.32320023 time: 0.0000s
# Epoch: 15001 loss: 9.32320023 time: 0.0000s
# Epoch: 20001 loss: 9.32320023 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 67.8377s
#
# 2 Layer dim 13
#
# Epoch: 0001 loss: 9.32319832 time: 0.0156s
# Epoch: 5001 loss: 9.06127644 time: 0.0156s
# Epoch: 10001 loss: 9.06127644 time: 0.0000s
# Epoch: 15001 loss: 9.06127644 time: 0.0000s
# Epoch: 20001 loss: 9.06127644 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 85.1277s
#
# Fixed Sigma dim 14
#
# Epoch: 0001 loss: 9.40320015 time: 0.0177s
# Epoch: 5001 loss: 9.39238739 time: 0.0156s
# Epoch: 10001 loss: 9.39082050 time: 0.0000s
# Epoch: 15001 loss: 9.38960648 time: 0.0000s
# Epoch: 20001 loss: 9.38873577 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 83.9151s
#
# Flexible Sigma dim 14
#
# Epoch: 0001 loss: 9.38873672 time: 0.0000s
# Epoch: 5001 loss: 9.07551765 time: 0.0150s
# Epoch: 10001 loss: 9.07551765 time: 0.0070s
# Epoch: 15001 loss: 9.07551765 time: 0.0000s
# Epoch: 20001 loss: 9.07551765 time: 0.0157s
# Optimization Finished!
# Total time elapsed: 67.1918s
#
# 2 Layer dim 14
#
# Epoch: 0001 loss: 9.07551670 time: 0.0000s
# Epoch: 5001 loss: 9.07551670 time: 0.0000s
# Epoch: 10001 loss: 9.07551670 time: 0.0157s
# Epoch: 15001 loss: 9.07551670 time: 0.0000s
# Epoch: 20001 loss: 9.07551670 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 86.6751s

# %%
plt.plot(dims,fix_loss,label="Fixed Sigma")
plt.plot(dims,nonfix_loss,label="Flexible Sigma")
plt.plot(dims,svd_loss,label="SVD")
plt.plot(dims,svdrelu_loss,label="SVD Relu")
plt.xlabel("dim")
plt.ylabel("NLL")
plt.legend()
